# %%
# Clustering/Dimensionality Reduction
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# DataScience
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the csv
df = pd.read_csv("myopia.csv")
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
#Drop the MYOPIC column
df.drop(columns=["MYOPIC"], inplace=True)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0        0    10         34      1      1
# 1        1     7         12      1      1
# 2        0    10         14      0      0
# 3        0     4         37      0      1
# 4        0     4          4      1      0

# %%
#Data needs to be numeric and not-null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AGE        618 non-null    int64
#  1   SPHEQ      618 non-null    float64
#  2   AL         618 non-null    float64
#  3   ACD        618 non-null    float64
#  4   LT         618 non-null    float64
#  5   VCD        618 non-null    float64
#  6   SPORTHR    618 non-null    int64
#  7   READHR     618 non-null    int64
#  8   COMPHR     618 non-null    int64
#  9   STUDYHR    618 non-null    int64
#  10  TVHR       618 non-null    int64
#  11  DIOPTERHR  618 non-null    int64
#  12  MOMMY      618 non-null    int64
#  13  DADMY      618 non-null    int64
# dtypes: float64(5), int64(9)
# memory usage: 67.7 KB

# %%
df.AGE.value_counts()
# Out:
# 6    456
# 7     82
# 8     53
# 5     21
# 9      6
# Name: AGE, dtype: int64

# %%
#Checks for obvious clustering
#Looks like top left and right will cluster

X = TSNE(learning_rate="auto").fit_transform(df)

plt.figure(figsize=(16,10))

plt.scatter(X[:, 0], X[:, 1])
plt.title("TSNE Plot")
plt.show()
# Out:
# C:\Users\hanng\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
#Initialize PCA Model

pca = PCA()
pca.fit(df)

plt.plot(range(len(df.columns)), pca.explained_variance_ratio_)
plt.xlabel(" Numbers of Principal Components")
plt.ylabel("Explained Variance")
plt.title("PCA Elbow")
plt.figure(figsize=(20,12))
plt.show()

# %%
#Elbows seem appear at 1, 2, 3 and possibly 5 (3 principal components are majority)

# %%
list(zip(range(len(df.columns)), pca.explained_variance_ratio_))
# Out:
# [(0, 0.7255724892053264),
#  (1, 0.16081428120782787),
#  (2, 0.07227215489674377),
#  (3, 0.02333858889043093),
#  (4, 0.012045721818095911),
#  (5, 0.0024839383449801926),
#  (6, 0.0010474125750545695),
#  (7, 0.000963275380648177),
#  (8, 0.0006603799884485662),
#  (9, 0.0005714584698331096),
#  (10, 0.00016195402559981653),
#  (11, 6.833523602788607e-05),
#  (12, 9.960982860078887e-09),
#  (13, 1.2079031337744814e-33)]

# %%
#There is a correlation (0 at 0.72 or 72%)

# %%
#Summary of correlation
df.corr()
# Out:
#                 AGE     SPHEQ        AL       ACD        LT       VCD  \
# AGE        1.000000 -0.118255  0.220784  0.191849 -0.185531  0.202472
# SPHEQ     -0.118255  1.000000 -0.305512 -0.238784  0.072699 -0.247130
# AL         0.220784 -0.305512  1.000000  0.456296 -0.328939  0.941916
# ACD        0.191849 -0.238784  0.456296  1.000000 -0.339291  0.199447
# LT        -0.185531  0.072699 -0.328939 -0.339291  1.000000 -0.451594
# VCD        0.202472 -0.247130  0.941916  0.199447 -0.451594  1.000000
# SPORTHR    0.057538 -0.022468  0.112004  0.075161 -0.032745  0.096235
# READHR     0.130194 -0.099501  0.017944  0.011481  0.018481  0.010120
# COMPHR     0.056929 -0.031088  0.086328  0.071666 -0.025345  0.069369
# STUDYHR    0.399324 -0.054873  0.098326  0.051826 -0.037580  0.091759
# TVHR       0.069395 -0.080934  0.077170 -0.042761  0.049095  0.082579
# DIOPTERHR  0.286820 -0.120611  0.111527  0.040157  0.002875  0.099774
# ...

# %%
#Principal compoments analysis
pca = PCA(n_components=3)
pca.fit(df)
# Out:
# PCA(n_components=3)

# %%
df1 = pd.DataFrame(pca.transform(df), columns=["PCA1", "PCA2", "PCA3"])
df1.head()
# Out:
#         PCA1       PCA2      PCA3
# 0  12.138059  31.636212 -4.526625
# 1 -15.268363  -6.095695  1.207074
# 2 -11.662239   3.755105  2.808212
# 3  11.235886   4.012566 -8.179565
# 4 -22.446506   4.580916 -1.817501

# %%
# Check for obvious clusters #2.
X = TSNE(learning_rate="auto").fit_transform(df)

plt.figure(figsize=(12,8))

plt.scatter(X[:, 0], X[:, 1])
plt.title("TSNE Plot")
plt.show()
# Out:
# C:\Users\hanng\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
#Does show many differences

# %%
#Kmeans model

inertia = []
k_range = list(range(2, 20))

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)
    
    inertia.append(kmeans.inertia_)
    
#Make the plot
plt.figure(figsize=(16,10))

plt.plot(k_range, inertia)
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Plot")

plt.show()

# %%
#Elbows seem to appears at a bit after 2.5 and a bit before 5 (slight elbow)

# %%
#KMeans cluster of 10

km = KMeans(n_clusters=10, random_state=42)
kmeans.fit(df)
preds = kmeans.predict(df)

plt.figure(figsize=(12,8))

plt.scatter(X[:, 0], X[:, 1], c=preds)
plt.title("TSNE Plot")
plt.show()

# %%
##Showing overlappings, 10 seems to be over fitting

# %%
#KMeans cluster of 8

km = KMeans(n_clusters=8, random_state=42)
kmeans.fit(df)
preds = kmeans.predict(df)

plt.figure(figsize=(12,8))

plt.scatter(X[:, 0], X[:, 1], c=preds)
plt.title("TSNE Plot")
plt.show()

# %%
##Showing overlappings, 8 seems to be over fitting

# %%
#KMeans cluster of 5

km = KMeans(n_clusters=5, random_state=42)
kmeans.fit(df)
preds = kmeans.predict(df)

plt.figure(figsize=(12,8))

plt.scatter(X[:, 0], X[:, 1], c=preds)
plt.title("TSNE Plot")
plt.show()

# %%
#Purple scatters, have interesting boundaries

# %%
#Dendrogram plot

mergings = linkage(df, method = "ward")

plt.figure(figsize=(20, 8))

dendrogram(mergings,leaf_rotation=90,leaf_font_size=5)

plt.show()

# %%
#Green is a clear cluster
#Orange spread out into about four groups, two of which could be combined to one.

# %%
cluster = AgglomerativeClustering(
    n_clusters=5,
    affinity="euclidean",
    linkage="ward"
)

preds = cluster.fit_predict(df)
plt.figure(figsize=(12,8))

plt.scatter(X[:, 0], X[:, 1], c=preds)
plt.title("TSNE Plot")
plt.show()

# %%
# Choose: kmean of 5 clusters as it shows clusters true to the form
